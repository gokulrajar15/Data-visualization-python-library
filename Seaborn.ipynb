# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
t = sns.load_dataset("tips")
x = pd.read_csv("D:\softwares\Sample.csv")

# %%
print(x)
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
sns.displot(x = t["size"],kde = True)

# %%
sns.displot(data = x, x = "Year")

# %%
sns.displot(data= x, x= "Direction")
plt.title("Directions")
# Out:
# Text(0.5, 1.0, 'Directions')

# %%
sns.jointplot(data = x, x = "Value", y = "Year", kind = "kde")

# %%
sns.jointplot(data = x, x = "Value", kind = "kde")

# %%
sns.jointplot(x = "Cumulative",y = "Year", data = x, kind = "hex")

# %%
sns.jointplot(data = t, x = "total_bill", y = "tip", kind = "reg")

# %%
sns.jointplot(data = t, x = "size", y = "total_bill", kind = "hex")

# %%
sns.jointplot(data = t, x = "tip", y  = "total_bill", kind = "resid")

# %%
sns.rugplot(data = x, x = "Year")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.rugplot(data = t, x = "size")
# Out:
# <AxesSubplot:xlabel='size'>

# %%
sns.pairplot(x)

# %%
sns.kdeplot(data = x, x = "Value")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Density'>

# %%
x
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data = x, x = "Year", y = "Value")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
sns.countplot(data = x, x = "Direction")
# Out:
# <AxesSubplot:xlabel='Direction', ylabel='count'>

# %%
sns.boxplot(data = x, x = "Year", y = "Value")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
sns.boxplot(data = t, x= "smoker", y = "tip", hue = "sex")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.violinplot(data = x, x = "Year", y = "Value")
plt.ylim(0,75000000)
# Out:
# (0.0, 75000000.0)

# %%
sns.boxplot(data = x, x = "Direction", y = "Value", hue = "Weekday")
# Out:
# <AxesSubplot:xlabel='Direction', ylabel='Value'>

# %%
sns.violinplot(data= t, x = "sex", y = "total_bill", hue = "smoker", split = True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.stripplot(data = t, x = "smoker", y = "sex")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='sex'>

# %%
sns.catplot(x='sex',y='total_bill',data=t,kind='bar')

# %%
x
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
z = x.pivot_table(index = "Weekday", columns = "Year", values = "Value")

# %%
z
# Out:
# Year               2015          2016          2017          2018  \
# Weekday
# Friday     2.928974e+07  2.991314e+07  3.213090e+07  3.453489e+07
# Monday     3.470361e+07  3.011633e+07  3.683390e+07  4.036955e+07
# Saturday   1.742616e+07  1.662011e+07  1.665543e+07  1.500895e+07
# Sunday     1.665103e+07  1.848052e+07  2.141830e+07  2.075779e+07
# Thursday   2.946506e+07  3.091202e+07  3.153773e+07  3.509155e+07
# Tuesday    2.686743e+07  2.613039e+07  2.640478e+07  3.288685e+07
# Wednesday  2.401695e+07  2.415453e+07  2.988737e+07  3.218518e+07
#
# Year               2019          2020          2021
# Weekday
# Friday     3.753173e+07  3.273329e+07  3.795645e+07
# Monday     3.341147e+07  3.758583e+07  3.593086e+07
# Saturday   1.421435e+07  1.426637e+07  1.981390e+07
# Sunday     2.011548e+07  1.769833e+07  2.103522e+07
# Thursday   3.415522e+07  3.281681e+07  4.059369e+07
# Tuesday    3.970889e+07  3.525205e+07  4.159033e+07
# ...

# %%
sns.heatmap(z, cmap = "Blues", linecolor = "white", linewidths = 1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Weekday'>

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
p  = iris.pivot_table(index = "species")

# %%
sns.heatmap(p)
# Out:
# <AxesSubplot:ylabel='species'>

# %%
c=sns.PairGrid(iris, hue = "species", palette = "rainbow").add_legend()
c.map_diag(plt.hist)
c.map_upper(plt.scatter)
c.map_lower(sns.kdeplot)

# %%
x
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
sns.lmplot(x='total_bill',y='tip',data=t,hue='sex',palette='coolwarm',
           markers= 'o',scatter_kws={'s':50}, aspect = 2, height = 20)
